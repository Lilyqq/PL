# %%
import pandas as pd

data = pd.read_csv("heho.csv")
data.head(10)
# Out:
#                              Title                                 Link  \
# 0        失智症有望透過中醫改善，中醫師傳授保養的四大穴位！  https://heho.com.tw/archives/273818
# 1                按這四大穴位，改善「胃食道逆流」！  https://heho.com.tw/archives/270648
# 2            按摩這三組穴位可有效紓解「慢性疲勞症候群」  https://heho.com.tw/archives/267950
# 3            「自律神經失調」會好嗎？這四穴位平衡身心靈  https://heho.com.tw/archives/265495
# 4   春天是養肝好時機！用 2 方法、壓 2 穴道為整年健康打根基  https://heho.com.tw/archives/262457
# 5    足底筋膜炎總讓你「寸步難行」？中醫推薦按摩 6 穴位助解痛  https://heho.com.tw/archives/259487
# 6           按壓這 4 穴位安定心神、疏肝解鬱又「養肝」  https://heho.com.tw/archives/259008
# 7                改善自律神經失調，４穴道啟動自癒力  https://heho.com.tw/archives/246433
# 8            腸胃炎上吐下瀉好困擾！手腳２穴位緩解不適感  https://heho.com.tw/archives/256044
# 9                 失眠睡不好，６穴道補氣紓壓助好眠  https://heho.com.tw/archives/244409
#
#                                                Image
# 0  https://heho.com.tw/wp-content/uploads/2023/05...
# 1  https://heho.com.tw/wp-content/uploads/2023/04...
# 2  https://heho.com.tw/wp-content/uploads/2023/03...
# 3  https://heho.com.tw/wp-content/uploads/2023/03...
# 4  https://heho.com.tw/wp-content/uploads/2023/02...
# 5  https://heho.com.tw/wp-content/uploads/2023/01...
# 6  https://heho.com.tw/wp-content/uploads/2023/01...
# 7  https://heho.com.tw/wp-content/uploads/2022/10...
# 8  https://heho.com.tw/wp-content/uploads/2022/12...
# 9  https://heho.com.tw/wp-content/uploads/2022/10...

# %%
data['Tag'] = " "
data.head(5)
# Out:
#                              Title                                 Link  \
# 0        失智症有望透過中醫改善，中醫師傳授保養的四大穴位！  https://heho.com.tw/archives/273818
# 1                按這四大穴位，改善「胃食道逆流」！  https://heho.com.tw/archives/270648
# 2            按摩這三組穴位可有效紓解「慢性疲勞症候群」  https://heho.com.tw/archives/267950
# 3            「自律神經失調」會好嗎？這四穴位平衡身心靈  https://heho.com.tw/archives/265495
# 4   春天是養肝好時機！用 2 方法、壓 2 穴道為整年健康打根基  https://heho.com.tw/archives/262457
#
#                                                Image Tag
# 0  https://heho.com.tw/wp-content/uploads/2023/05...
# 1  https://heho.com.tw/wp-content/uploads/2023/04...
# 2  https://heho.com.tw/wp-content/uploads/2023/03...
# 3  https://heho.com.tw/wp-content/uploads/2023/03...
# 4  https://heho.com.tw/wp-content/uploads/2023/02...

# %%
#文字探勘
import jieba
import jieba.analyse
import pandas as pd
import numpy as np
from collections import Counter

# %%
# 測試結巴功能
documents = ["我是師大Jisoo"]
# 精確模式
for sentence in documents:
    test = jieba.cut(sentence)
    print('/'.join(test))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Lily\AppData\Local\Temp\jieba.cache
# Loading model cost 1.041 seconds.
# Prefix dict has been built successfully.
# 我/是/師大/Jisoo

# %%
import csv
jieba.load_userdict('dict1.txt')
data1 = []

# 打開CSV文件
with open('heho.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    
    # 逐行讀取CSV數據
    for row in reader:
        title = row['Title']
        
        # 使用jieba進行分詞
        
        keywords = jieba.lcut(title, HMM=False)
       
        # 過濾出詞彙表中的詞
        with open('dict1.txt', 'r', encoding='utf-8') as dict_file:
            dict1 = dict_file.read().splitlines()  # 讀取詞彙表文件並按行分割為列表
        
        selected_keywords = [word for word in keywords if word in dict1]
        
        # 將標點符號去除
        selected_keywords = [word.replace('[','').replace(']','').replace(',', '') for word in selected_keywords]
        
        #print(selected_keywords)
        
        data1.append([selected_keywords])

tag_data = pd.DataFrame(data1, columns=['Tag'])
tag_data
# Out:
#                  Tag
# 0          [失智症, 保養]
# 1            [胃食道逆流]
# 2          [慢性疲勞症候群]
# 3    [自律神經失調, 平衡身心靈]
# 4           [春天, 養肝]
# ..               ...
# 166            [腦中風]
# 167     [冬季, 養生, 養腎]
# 168          [腳, 腳背]
# 169             [經痛]
# 170           [肩頸酸痛]
#
# [171 rows x 1 columns]

# %%
tag_data.to_csv('Tag.csv', index=False)

# %%
data['Tag'] = tag_data['Tag']
data
# Out:
#                                Title                                 Link  \
# 0          失智症有望透過中醫改善，中醫師傳授保養的四大穴位！  https://heho.com.tw/archives/273818
# 1                  按這四大穴位，改善「胃食道逆流」！  https://heho.com.tw/archives/270648
# 2              按摩這三組穴位可有效紓解「慢性疲勞症候群」  https://heho.com.tw/archives/267950
# 3              「自律神經失調」會好嗎？這四穴位平衡身心靈  https://heho.com.tw/archives/265495
# 4     春天是養肝好時機！用 2 方法、壓 2 穴道為整年健康打根基  https://heho.com.tw/archives/262457
# ..                               ...                                  ...
# 166             按這些穴位就對了！幫助降低你的腦中風危機    https://heho.com.tw/archives/3858
# 167                    冬季養生先養腎，術養四穴位    https://heho.com.tw/archives/3723
# 168                穴位不再只在腳底啦！！！腳背也可以    https://heho.com.tw/archives/2716
# 169                          緩解經痛4穴位    https://heho.com.tw/archives/1557
# 170                      舒緩肩頸酸痛的重要穴位    https://heho.com.tw/archives/1523
#
#                                                  Image              Tag
# 0    https://heho.com.tw/wp-content/uploads/2023/05...        [失智症, 保養]
# 1    https://heho.com.tw/wp-content/uploads/2023/04...          [胃食道逆流]
# 2    https://heho.com.tw/wp-content/uploads/2023/03...        [慢性疲勞症候群]
# 3    https://heho.com.tw/wp-content/uploads/2023/03...  [自律神經失調, 平衡身心靈]
# 4    https://heho.com.tw/wp-content/uploads/2023/02...         [春天, 養肝]
# ..                                                 ...              ...
# 166  https://heho.com.tw/wp-content/uploads/2017/12...            [腦中風]
# 167  https://heho.com.tw/wp-content/uploads/2017/12...     [冬季, 養生, 養腎]
# 168  https://heho.com.tw/wp-content/uploads/2017/11...          [腳, 腳背]
# 169  https://heho.com.tw/wp-content/uploads/2017/10...             [經痛]
# 170  https://heho.com.tw/wp-content/uploads/2017/10...           [肩頸酸痛]
#
# [171 rows x 4 columns]

# %%
data.to_csv('heho_tag.csv', index=False)
